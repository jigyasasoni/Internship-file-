# %%
import pandas as pd
import numpy as np
import zipfile
import openpyxl
import os
from sklearn import datasets
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install --upgrade pandas xlrd
# Out:
# Requirement already satisfied: pandas in c:\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: xlrd in c:\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install --upgrade pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: openpyxl in c:\anaconda3\lib\site-packages (3.1.2)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: et-xmlfile in c:\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import requests
print("timeout = 0.001")
try:
    r = requests.get('https://github.com/', timeout = 0.001)
    print(r.text)
except requests.exceptions.RequestException as e:
    print(e)    

print("\ntimeout = 1.0")    
try:
    r = requests.get('https://github.com/', timeout = 1.0)
    print("Connected....!")
except requests.exceptions.RequestException as e:
    print(e)
# Out:
# timeout = 0.001
# HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000148342FD690>, 'Connection to github.com timed out. (connect timeout=0.001)'))
#
# timeout = 1.0
# Connected....!

# %%
download_path = ('c:\\Users\\jigya\\Downloads\\Grades.csv')
save_path = ('c:\\Users\\jigya\\Downloads\\Grades.csv')

# %%
import os

file_path = ('c:\\Users\\jigya\\Downloads\\Grades.csv')
print(os.path.exists(file_path))
# Out:
# True

# %%
df= pd.read_csv("Grades.csv")
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.tail()
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# 569      C  2.193
# 570     C-  1.753
#
# [5 rows x 43 columns]

# %%
df.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
#  19  CS-214     565 non-null    object
#  20  EE-217     565 non-null    object
#  21  CS-212     565 non-null    object
#  22  CS-215     565 non-null    object
#  23  MT-331     562 non-null    object
#  24  EF-303     561 non-null    object
#  25  HS-304     561 non-null    object
#  26  CS-301     561 non-null    object
#  27  CS-302     561 non-null    object
#  28  TC-383     561 non-null    object
#  29  MT-442     561 non-null    object
#  30  EL-332     562 non-null    object
#  31  CS-318     562 non-null    object
#  32  CS-306     562 non-null    object
#  33  CS-312     561 non-null    object
#  34  CS-317     559 non-null    object
#  35  CS-403     559 non-null    object
#  36  CS-421     559 non-null    object
#  37  CS-406     486 non-null    object
#  38  CS-414     558 non-null    object
#  39  CS-419     558 non-null    object
#  40  CS-423     557 non-null    object
#  41  CS-412     492 non-null    object
#  42  CGPA       571 non-null    float64
# dtypes: float64(1), object(42)
# memory usage: 191.9+ KB

# %%
print('Total numbers of students:',len(df))
# Out:
# Total numbers of students: 571

# %%
df.isnull().any()
# Out:
# Seat No.     False
# PH-121       False
# HS-101       False
# CY-105        True
# HS-105/12     True
# MT-111        True
# CS-105       False
# CS-106        True
# EL-102        True
# EE-119        True
# ME-107        True
# CS-107        True
# HS-205/20     True
# MT-222        True
# EE-222        True
# MT-224        True
# CS-210        True
# CS-211        True
# CS-203        True
# CS-214        True
# EE-217        True
# CS-212        True
# CS-215        True
# MT-331        True
# EF-303        True
# HS-304        True
# CS-301        True
# CS-302        True
# TC-383        True
# MT-442        True
# EL-332        True
# CS-318        True
# CS-306        True
# CS-312        True
# CS-317        True
# CS-403        True
# CS-421        True
# CS-406        True
# CS-414        True
# CS-419        True
# CS-423        True
# CS-412        True
# CGPA         False
# dtype: bool

# %% [markdown]
# # Data Visualization

# %%
sns.heatmap(df.isnull(),cmap='rainbow',yticklabels=False)
# Out:
# <Axes: >

# %%
sns.heatmap(df.isnull(),cmap="viridis",yticklabels=False)
# Out:
# <Axes: >

# %% [markdown]
# .There are some null values are present in the dataset

# %%
df.replace(np.nan,0, inplace = True)
df.head(10)
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
# 5  CS-97006      A     B-      B        D+     C+     A-     C+      B     B+
# 6  CS-97007     B-     C-     A-         D     A-      B      A     B+     A-
# 7  CS-97008     B+     B+     C+         C      C     A-     C-     A-      B
# 8  CS-97009     A-      C     A-        D+      B     A-     A-     A-     B+
# 9  CS-97010      A      B     C+         B      B     A-      C     B-     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
# 5  ...      C     B-     C+     C+     A-     A-     B+     B-      B  3.026
# 6  ...     B-      C     B+     B-      A     A-     B+     B+      A  2.957
# 7  ...     D+     B+     B+      C      A     B+     A-     A-     A-  3.043
# 8  ...     B+      B     B-     C+      A     A-     B+     A-      A  3.358
# 9  ...     C+     B-     B+     B-      A      A     A-      B      A  3.247
#
# [10 rows x 43 columns]

# %%
input = df.drop(["CS-403","CS-421","CS-406","CS-414","CS-419","CS-423","CS-412", 'MT-442',"Seat No.","CGPA"], axis=1)
target = df[["CGPA"]]

# %%
target.head()
# Out:
#     CGPA
# 0  2.205
# 1  2.008
# 2  3.608
# 3  1.906
# 4  3.448

# %%
pd.unique(df["PH-121"])
# Out:
# array(['B-', 'A', 'D', 'A-', 'B+', 'B', 'C+', 'C', 'C-', 'D+', 'WU', 'A+',
#        'F'], dtype=object)

# %%
type(input)
# Out:
# pandas.core.frame.DataFrame

# %%
grades_enc = {'B-':2.7, 'A':4, 'D':1.0, 'A-':3.7, 'B+':3.4, 'B':3.0, 'C+':2.4, 'C':2.0, 'C-':1.7, 'D+':1.4, 'WU':0.0, 'A+':4.4,'F':1.5}

# %%
for item in input:
      input[item] = input[item].replace(grades_enc)

input.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7     2.7
# 1     4.0     1.0     1.4        1.0     2.7     2.0     1.0     4.0     1.4
# 2     4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4     3.7
# 3     1.0     2.4     1.4        1.0     1.0     3.7     1.4     1.7     1.0
# 4     3.7     3.7     3.7        3.4     4.0     4.0     3.7     3.4     4.0
#
#    ME-107  ... EF-303  HS-304 CS-301 CS-302 TC-383 EL-332 CS-318 CS-306  \
# 0     1.7  ...    1.7     2.4    3.0    2.0    2.4    2.0    1.7    2.0
# 1     1.0  ...    1.0     1.7    3.7    1.4    1.7    2.0    3.7    1.0
# 2     3.7  ...    2.4       4    3.4    3.7    3.0    3.4    3.7    3.7
# 3     2.4  ...    1.0     2.7    1.0    2.7    1.4    1.4    3.4    1.7
# 4     3.7  ...    1.7     3.7    2.7    3.7    2.4    3.7    2.7    3.7
#
#   CS-312  CS-317
# 0    1.7     1.7
# 1    1.4     1.0
# 2    3.0     3.0
# 3    1.4     2.0
# 4    2.7     3.4
#
# [5 rows x 33 columns]

# %%
df = pd.concat([input, target], axis=1)

# %% [markdown]
# # Discover and Visualize the Data to Gain Insights:

# %%
df.hist(bins=30,figsize=(30,15))
plt.show()

# %% [markdown]
# # Looking for Correlations

# %%
df.describe()
# Out:
#            PH-121    HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.0000  571.000000  571.000000  571.000000  571.000000
# mean     3.036427    2.6338    3.287040    2.905429    3.009457    3.359370
# std      0.983979    0.9078    0.947336    1.043991    0.962224    0.831483
# min      0.000000    1.0000    0.000000    0.000000    0.000000    1.000000
# 25%      2.400000    2.0000    2.700000    2.000000    2.400000    3.000000
# 50%      3.400000    2.7000    3.700000    3.000000    3.400000    3.700000
# 75%      3.700000    3.4000    4.000000    3.700000    3.700000    4.000000
# max      4.400000    4.4000    4.400000    4.400000    4.400000    4.400000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-212  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     2.967426    2.992820    3.024343    2.709457  ...    2.783012
# std      0.866506    1.000772    0.845350    1.027490  ...    0.941225
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      2.400000    2.400000    2.400000    1.700000  ...    2.000000
# 50%      3.000000    3.400000    3.400000    2.700000  ...    3.000000
# 75%      3.700000    3.700000    3.700000    3.700000  ...    3.700000
# max      4.400000    4.400000    4.400000    4.400000  ...    4.400000
#
#            MT-331      EF-303      CS-301      CS-302      TC-383      EL-332  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     3.055166    2.501926    2.859720    3.056392    2.892469    2.901401
# std      1.016592    0.827327    0.973521    0.885343    1.032318    0.977357
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.400000    2.000000    2.000000    2.700000    2.000000    2.000000
# 50%      3.400000    2.700000    3.000000    3.400000    3.000000    3.000000
# 75%      4.000000    3.000000    3.700000    3.700000    3.700000    3.700000
# max      4.400000    4.000000    4.400000    4.400000    4.400000    4.400000
#
#            CS-306      CS-317        CGPA
# count  571.000000  571.000000  571.000000
# mean     2.907005    2.675832    2.954888
# std      0.981953    0.925247    0.620552
# min      0.000000    0.000000    0.800000
# 25%      2.400000    2.000000    2.538000
# 50%      3.000000    2.700000    3.029000
# 75%      3.700000    3.400000    3.451000
# max      4.400000    4.400000    3.985000
#
# [8 rows x 22 columns]

# %%
df.to_csv('cleaned_data.csv')

# %%
model1_columns = []
model2_columns = []
model3_columns = []
for item in [input]:

    for i in item:
        if i[3]=='1':
            model1_columns.append(i)
        elif i[3]=='2':
            model2_columns.append(i)
        else:
            model3_columns.append(i)
model2_columns = model1_columns + model2_columns
model3_columns = model2_columns + model3_columns

# %% [markdown]
# # Prepare the data for Linear Regression:
# Model 1: Predict final CGPA based on GPs of first year only.

# %%
labels = df['CGPA'].values
features = df[list(model1_columns)].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.30)

# %%
from sklearn import linear_model

lr_1 = linear_model.LinearRegression()

lr_1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
input_lr=[]
input_lr.append([4, 3.0, 0, 0, 0, 1.0, 4, 2.0, 0, 4, 4])
print(input_lr )
print(lr_1.predict(input_lr ))
# Out:
# [[4, 3.0, 0, 0, 0, 1.0, 4, 2.0, 0, 4, 4]]
# [1.89674977]

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error

mse_train = mean_squared_error(y_train, y_train_predict)
mae_train = mean_absolute_error(y_train, y_train_predict)
print("The model performance for training set")
print('RMSE is {}'.format(np.sqrt(mse_train)))
print('MAE is {}'.format(mae_train))
print("---------------------------------------")

mse_test = mean_squared_error(y_test, y_test_predict) 
mae_test = mean_absolute_error(y_test, y_test_predict) 
print("The model performance for testing set")
print('RMSE is {}'.format(np.sqrt(mse_test)))
print('MAE is {}'.format(mae_test))

print("---------------------------------------")
test_score= lr_1.score(X_test, y_test) 
print("The score of model for testing set")
print('Test score {}'.format(test_score.round(2)))
# Out:
# The model performance for training set
# RMSE is 0.23287185128656837
# MAE is 0.17963768768225274
# ---------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 10
#       7 print('MAE is {}'.format(mae_train))
#       8 print("---------------------------------------")
# ---> 10 mse_test = mean_squared_error(y_test, y_test_predict)
#      11 mae_test = mean_absolute_error(y_test, y_test_predict)
#      12 print("The model performance for testing set")
#
# NameError: name 'y_test_predict' is not defined

# %%
compare={"Actual": y_test, "Predict": y_test_predict}
pd.DataFrame(compare)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 compare={"Actual": y_test, "Predict": y_test_predict}
#       2 pd.DataFrame(compare)
#
# NameError: name 'y_test_predict' is not defined
